# %% [markdown]
# # 🎮 Jogo de Pedra, Papel e Tesoura com Inteligência Artificial
#
# Neste notebook você vai treinar um robô para reconhecer as suas jogadas de **pedra**, **papel** e **tesoura** usando a webcam, e depois jogar contra ele!
#
# O passo a passo é sempre o mesmo:
#
# 1. **Tirar fotos** de cada jogada (`tirar_fotos`)
# 2. **Treinar** o robô com essas fotos (`treinar`)
# 3. **Testar** se o robô aprendeu bem (`testar`)
# 4. **Jogar** de verdade contra o computador (`jogar`)
#
# Execute as células de cima para baixo, uma de cada vez (clique na célula e pressione `Shift + Enter`).

# %%
# %matplotlib inline
from ia_pedra_papel_tesoura import tirar_fotos, treinar, testar, jogar

print("Tudo pronto! Vamos começar 🚀")

# %% [markdown]
# ## Passo 1 — Tirar fotos 📸
#
# Uma janela da webcam vai abrir. Faça a pose pedida, pressione **ESPAÇO** para tirar cada foto e **ESC** se quiser parar antes.
#
# Tire pelo menos **20 fotos de cada jogada**, mexendo um pouco a mão e mudando o fundo entre as fotos — isso ajuda o robô a aprender melhor. Você pode rodar `tirar_fotos(...)` mais de uma vez para adicionar mais fotos depois.

# %%
tirar_fotos("pedra", quantidade=20)

# %%
tirar_fotos("papel", quantidade=20)

# %%
tirar_fotos("tesoura", quantidade=20)

# %% [markdown]
# ## Passo 2 — Treinar o robô 🧠
#
# Agora o robô vai olhar todas as fotos que você tirou e aprender a diferença entre pedra, papel e tesoura. Isso pode demorar um pouco — acompanhe o gráfico no final para ver como ele foi aprendendo.
#
# Se quiser, pode chamar `treinar()` de novo depois de tirar mais fotos, para o robô aprender ainda melhor.

# %%
treinar()

# %% [markdown]
# ## Passo 3 — Testar o robô 🔍
#
# Vamos ver se o robô aprendeu direito! Rode a célula abaixo, mostre uma jogada para a webcam e pressione **ESPAÇO**. O robô vai dizer o que ele acha que você mostrou, e o quão confiante ele está.
#
# Teste várias vezes, com jogadas diferentes. Se ele errar muito, volte ao Passo 1 e tire mais fotos (principalmente da jogada que ele confundiu).

# %%
testar()

# %% [markdown]
# ## Passo 4 — Jogar! 🎉
#
# Chegou a hora de jogar de verdade! Mostre sua jogada para a webcam, pressione **ESPAÇO**, e veja se você venceu o computador.
#
# Pode rodar essa célula quantas vezes quiser para jogar de novo.

# %%
jogar()
